# %% [markdown]
# ## Advanced PySpark Transformations
#
# Now we will take this another notch up by doing more complex transformations in PySpark
#
# Let's load our data and get started!

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

df = spark.read.csv('/Volumes/workspace/default/tutorial_files/BigMartSales.csv', header=True, inferSchema=True)

# %% [markdown]
# ### PIVOT

# %%
df.groupBy('Item_Type').pivot('Outlet_Size').agg(avg('Item_MRP'))\
    .sort('Item_Type').limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Item_Type</th><th>null</th><th>High</th><th>Medium</th><th>Small</th></tr></thead><tbody><tr><td>Baking Goods</td><td>126.66939891891889</td><td>129.20204383561642</td><td>126.17856847290639</td><td>125.21336363636368</td></tr><tr><td>Breads</td><td>139.04861666666667</td><td>133.75896</td><td>140.8610385542169</td><td>145.5236507042254</td></tr><tr><td>Breakfast</td><td>158.6750903225807</td><td>147.49058461538462</td><td>134.53751111111112</td><td>130.56802666666667</td></tr><tr><td>Canned</td><td>140.65181123595508</td><td>135.4427076923077</td><td>138.12485069124423</td><td>142.29542857142857</td></tr><tr><td>Dairy</td><td>149.0512677419355</td><td>153.50917249999995</td><td>148.51217431192666</td><td>145.94210101010103</td></tr><tr><td>Frozen Foods</td><td>137.49448464730293</td><td>136.82925</td><td>140.55701532846714</td><td>137.83854377510033</td></tr><tr><td>Fruits and Vegetables</td><td>142.57516045845267</td><td>145.57287042253515</td><td>142.9714702179177</td><td>148.31336951219507</td></tr><tr><td>Hard Drinks</td><td>134.3875333333333</td><td>141.9275217391304</td><td>142.83769599999994</td><td>129.758784</td></tr><tr><td>Health and Hygiene</td><td>130.55989019607844</td><td>135.11098032786884</td><td>128.70186470588237</td><td>131.83153529411757</td></tr><tr><td>Household</td><td>147.76930421455944</td><td>147.09752233009704</td><td>147.71133010380618</td><td>153.9654389105058</td></tr></tbody></table></div>

# %% [markdown]
# ### When-Otherwise
# #### Problem 1: Flag records as Veg or Non Veg based on the `Item_Type` using When-Otherwise

# %%
df.withColumn('Veg_Flag', when(col('Item_Type') == 'Meat', 'Non-Veg').otherwise('Veg')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Item_Identifier</th><th>Item_Weight</th><th>Item_Fat_Content</th><th>Item_Visibility</th><th>Item_Type</th><th>Item_MRP</th><th>Outlet_Identifier</th><th>Outlet_Establishment_Year</th><th>Outlet_Size</th><th>Outlet_Location_Type</th><th>Outlet_Type</th><th>Item_Outlet_Sales</th><th>Veg_Flag</th></tr></thead><tbody><tr><td>FDA15</td><td>9.3</td><td>Low Fat</td><td>0.016047301</td><td>Dairy</td><td>249.8092</td><td>OUT049</td><td>1999</td><td>Medium</td><td>Tier 1</td><td>Supermarket Type1</td><td>3735.138</td><td>Veg</td></tr><tr><td>DRC01</td><td>5.92</td><td>Regular</td><td>0.019278216</td><td>Soft Drinks</td><td>48.2692</td><td>OUT018</td><td>2009</td><td>Medium</td><td>Tier 3</td><td>Supermarket Type2</td><td>443.4228</td><td>Veg</td></tr><tr><td>FDN15</td><td>17.5</td><td>Low Fat</td><td>0.016760075</td><td>Meat</td><td>141.618</td><td>OUT049</td><td>1999</td><td>Medium</td><td>Tier 1</td><td>Supermarket Type1</td><td>2097.27</td><td>Non-Veg</td></tr><tr><td>FDX07</td><td>19.2</td><td>Regular</td><td>0.0</td><td>Fruits and Vegetables</td><td>182.095</td><td>OUT010</td><td>1998</td><td>null</td><td>Tier 3</td><td>Grocery Store</td><td>732.38</td><td>Veg</td></tr><tr><td>NCD19</td><td>8.93</td><td>Low Fat</td><td>0.0</td><td>Household</td><td>53.8614</td><td>OUT013</td><td>1987</td><td>High</td><td>Tier 3</td><td>Supermarket Type1</td><td>994.7052</td><td>Veg</td></tr></tbody></table></div>

# %% [markdown]
# #### Problem 2: Create a new column to categorize if an item is Veg and under 100 MRP, Veg and over and Non-Veg

# %%
df.withColumn('Veg_Expensive', when((col('Item_Type') != 'Meat') & (col("Item_MRP") > 100), 'Veg-Expensive')\
    .when((col('Item_Type') != 'Meat') & (col('Item_MRP') <= 100), 'Veg-Inexpensive')\
        .otherwise('Non-Veg')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Item_Identifier</th><th>Item_Weight</th><th>Item_Fat_Content</th><th>Item_Visibility</th><th>Item_Type</th><th>Item_MRP</th><th>Outlet_Identifier</th><th>Outlet_Establishment_Year</th><th>Outlet_Size</th><th>Outlet_Location_Type</th><th>Outlet_Type</th><th>Item_Outlet_Sales</th><th>Veg_Expensive</th></tr></thead><tbody><tr><td>FDA15</td><td>9.3</td><td>Low Fat</td><td>0.016047301</td><td>Dairy</td><td>249.8092</td><td>OUT049</td><td>1999</td><td>Medium</td><td>Tier 1</td><td>Supermarket Type1</td><td>3735.138</td><td>Veg-Expensive</td></tr><tr><td>DRC01</td><td>5.92</td><td>Regular</td><td>0.019278216</td><td>Soft Drinks</td><td>48.2692</td><td>OUT018</td><td>2009</td><td>Medium</td><td>Tier 3</td><td>Supermarket Type2</td><td>443.4228</td><td>Veg-Inexpensive</td></tr><tr><td>FDN15</td><td>17.5</td><td>Low Fat</td><td>0.016760075</td><td>Meat</td><td>141.618</td><td>OUT049</td><td>1999</td><td>Medium</td><td>Tier 1</td><td>Supermarket Type1</td><td>2097.27</td><td>Non-Veg</td></tr><tr><td>FDX07</td><td>19.2</td><td>Regular</td><td>0.0</td><td>Fruits and Vegetables</td><td>182.095</td><td>OUT010</td><td>1998</td><td>null</td><td>Tier 3</td><td>Grocery Store</td><td>732.38</td><td>Veg-Expensive</td></tr><tr><td>NCD19</td><td>8.93</td><td>Low Fat</td><td>0.0</td><td>Household</td><td>53.8614</td><td>OUT013</td><td>1987</td><td>High</td><td>Tier 3</td><td>Supermarket Type1</td><td>994.7052</td><td>Veg-Inexpensive</td></tr></tbody></table></div>

# %% [markdown]
# ### JOINs

# %%
dataj1 = [('1','Jon','l01'),
          ('2','Robb','l02'),
          ('3','Aarya','l02'),
          ('4','Cersie','l03'),
          ('5','Jamie','l03'),
          ('6','Tyrion','l05'),
          ('7','Daenerys','l05'),
          ('8', 'Margaery', 'l06')] 

schemaj1 = 'char_id STRING, char_name STRING, location_id STRING' 

df1 = spark.createDataFrame(dataj1,schemaj1)

dataj2 = [('l01','The Wall'),
          ('l02','Winterfell'),
          ('l03','Kings Landing'),
          ('l04','Beyond'),
          ('l05','Dragonstone')]

schemaj2 = 'location_id STRING, location STRING'

df2 = spark.createDataFrame(dataj2,schemaj2)

# %%
df1.display()
df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th></tr></thead><tbody><tr><td>1</td><td>Jon</td><td>l01</td></tr><tr><td>2</td><td>Rob</td><td>l02</td></tr><tr><td>3</td><td>Aarya</td><td>l02</td></tr><tr><td>4</td><td>Cersie</td><td>l03</td></tr><tr><td>5</td><td>Jamie</td><td>l03</td></tr><tr><td>6</td><td>Tyrion</td><td>l05</td></tr><tr><td>7</td><td>Daenerys</td><td>l05</td></tr><tr><td>8</td><td>Margaery</td><td>l06</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_id</th><th>location</th></tr></thead><tbody><tr><td>l01</td><td>The Wall</td></tr><tr><td>l02</td><td>Winterfell</td></tr><tr><td>l03</td><td>Kings Landing</td></tr><tr><td>l04</td><td>Beyond</td></tr><tr><td>l05</td><td>Dragonstone</td></tr></tbody></table></div>

# %% [markdown]
# #### Inner Join

# %%
df1.join(df2, df1['location_id'] == df2['location_id'], 'inner').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th><th>location_id</th><th>location</th></tr></thead><tbody><tr><td>1</td><td>Jon</td><td>l01</td><td>l01</td><td>The Wall</td></tr><tr><td>2</td><td>Rob</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>3</td><td>Aarya</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>4</td><td>Cersie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>5</td><td>Jamie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>6</td><td>Tyrion</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>7</td><td>Daenerys</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr></tbody></table></div>

# %% [markdown]
# #### Left Join

# %%
df1.join(df2, df1['location_id'] == df2['location_id'], 'left').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th><th>location_id</th><th>location</th></tr></thead><tbody><tr><td>1</td><td>Jon</td><td>l01</td><td>l01</td><td>The Wall</td></tr><tr><td>2</td><td>Rob</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>3</td><td>Aarya</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>4</td><td>Cersie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>5</td><td>Jamie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>6</td><td>Tyrion</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>7</td><td>Daenerys</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>8</td><td>Margaery</td><td>l06</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #### Right Join

# %%
df1.join(df2, df1['location_id'] == df2['location_id'], 'right').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th><th>location_id</th><th>location</th></tr></thead><tbody><tr><td>1</td><td>Jon</td><td>l01</td><td>l01</td><td>The Wall</td></tr><tr><td>3</td><td>Aarya</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>2</td><td>Rob</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>5</td><td>Jamie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>4</td><td>Cersie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>null</td><td>null</td><td>null</td><td>l04</td><td>Beyond</td></tr><tr><td>7</td><td>Daenerys</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>6</td><td>Tyrion</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr></tbody></table></div>

# %% [markdown]
# #### Anti Join

# %%
df1.join(df2, df1['location_id'] == df2['location_id'], 'anti').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th></tr></thead><tbody><tr><td>8</td><td>Margaery</td><td>l06</td></tr></tbody></table></div>

# %% [markdown]
# #### Full Join

# %%
df1.join(df2, df1['location_id'] == df2['location_id'], 'full').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>char_id</th><th>char_name</th><th>location_id</th><th>location_id</th><th>location</th></tr></thead><tbody><tr><td>1</td><td>Jon</td><td>l01</td><td>l01</td><td>The Wall</td></tr><tr><td>2</td><td>Rob</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>3</td><td>Aarya</td><td>l02</td><td>l02</td><td>Winterfell</td></tr><tr><td>4</td><td>Cersie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>5</td><td>Jamie</td><td>l03</td><td>l03</td><td>Kings Landing</td></tr><tr><td>6</td><td>Tyrion</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>7</td><td>Daenerys</td><td>l05</td><td>l05</td><td>Dragonstone</td></tr><tr><td>8</td><td>Margaery</td><td>l06</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>l04</td><td>Beyond</td></tr></tbody></table></div>
